# %%
from sqlalchemy import create_engine, text
from sqlalchemy import text
import psycopg2
import psycopg2.extras
import json
import os
import pandas as pd
import requests
import ipywidgets as widgets
import geopandas as gpd
import numpy as np
from shapely.geometry import Point, Polygon, MultiPolygon
from geoalchemy2 import Geometry, WKTElement
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

def display_image(response, w=200, h=300):
    return widgets.Image(value=response.content, format='jpg', width=w, height=h)

credentials = "Credentials.json"

def pgconnect(credential_filepath, db_schema="public"):
    with open(credential_filepath) as f:
        db_conn_dict = json.load(f)
        host       = db_conn_dict['host']
        db_user    = db_conn_dict['user']
        db_pw      = db_conn_dict['password']
        default_db = db_conn_dict['user']
        port       = db_conn_dict['port']
        try:
            db = create_engine(f'postgresql+psycopg2://{db_user}:{db_pw}@{host}:{port}/{default_db}', echo=False)
            conn = db.connect()
            print('Connected successfully.')
        except Exception as e:
            print("Unable to connect to the database.")
            print(e)
            db, conn = None, None
        return db,conn

def query(conn, sqlcmd, args=None, df=True):
    result = pd.DataFrame() if df else None
    try:
        if df:
            result = pd.read_sql_query(sqlcmd, conn, params=args)
        else:
            result = conn.execute(text(sqlcmd), args).fetchall()
            result = result[0] if len(result) == 1 else result
    except Exception as e:
        print("Error encountered: ", e, sep='\n')
    return result

db, conn = pgconnect(credentials)

from sqlalchemy import text
conn.execute(text("set search_path to sa2project"))
# Out:
# Connected successfully.

# %%
conn.commit()
conn.execute(text("""
DROP TABLE IF EXISTS businesses CASCADE;
CREATE TABLE businesses(
   industry_code TEXT,
   industry_name TEXT,
   sa2_code TEXT,
   sa2_name TEXT,
   "0_to_50k_businesses" INTEGER NOT NULL,
   "50k_to_200k_businesses" integer NOT NULL,
   "200k_to_2m_businesses" integer NOT NULL,
   "2m_to_5m_businesses" integer NOT NULL,
   "5m_to_10m_businesses" integer NOT NULL,
   "10m_or_more_businesses" integer NOT NULL,
   total_businesses integer
);"""))
businessdata = pd.read_csv('businesses.csv')
businessdata.columns = map(str.lower, businessdata.columns)
businessdata.to_sql("businesses", con=conn, if_exists='append', index=False)
# Out:
# 217

# %%
conn.commit()
conn.execute(text("""
DROP TABLE IF EXISTS income CASCADE;
CREATE TABLE income(
    sa2_code21 integer,
    sa2_name text,
    earners integer,
    median_age integer,
    median_income integer,
    mean_income integer
);"""))
incomedata = pd.read_csv('income.csv')
incomedata.columns = map(str.lower, incomedata.columns)
numeric_columns = ['earners', 'median_age', 'median_income', 'mean_income']
for col in numeric_columns:
    if col in incomedata.columns:
        incomedata[col] = pd.to_numeric(incomedata[col], errors='coerce')
incomedata.to_sql("income", con=conn, if_exists='append', index=False)
# Out:
# 642

# %%
conn.commit()
conn.execute(text("""
DROP TABLE IF EXISTS population CASCADE;
CREATE TABLE population(
    sa2_code integer,
    sa2_name text,
    "0-4_people" INTEGER,
    "5-9_people" INTEGER,
    "10-14_people" INTEGER,
    "15-19_people" INTEGER,
    "20-24_people" INTEGER,
    "25-29_people" INTEGER,
    "30-34_people" INTEGER,
    "35-39_people" INTEGER,
    "40-44_people" INTEGER,
    "45-49_people" INTEGER,
    "50-54_people" INTEGER,
    "55-59_people" INTEGER,
    "60-64_people" INTEGER,
    "65-69_people" INTEGER,
    "70-74_people" INTEGER,
    "75-79_people" INTEGER,
    "80-84_people" INTEGER,
    "85-and-over_people" INTEGER,
    "total_people" INTEGER
);"""))
populationdata = pd.read_csv('population.csv')
populationdata.columns = map(str.lower, populationdata.columns)
populationdata.to_sql("population", con=conn, if_exists='append', index=False)
# Out:
# 373

# %%
import geopandas as gpd
from shapely.geometry import Point
from sqlalchemy import text
conn.execute(text("SET search_path TO sa2project, public")) # Ensure schema context
conn.commit()

create_stops_table_sql = """
DROP TABLE IF EXISTS STOPS CASCADE;
CREATE TABLE STOPS (
    stop_id VARCHAR(20) PRIMARY KEY, -- Added PRIMARY KEY constraint
    stop_code VARCHAR(20),
    stop_name TEXT,
    location_type VARCHAR(5),
    parent_station VARCHAR(20),
    wheelchair_boarding INTEGER,
    platform_code VARCHAR(20),
    -- Added geometry column with Point type and SRID 4326 (WGS84 for lat/lon)
    geometry GEOMETRY(Point, 4326)
);
"""
try:
    conn.execute(text(create_stops_table_sql))
    conn.commit()

    # Load data using pandas and geopandas
    print("Reading Stops.txt...")
    stops_df = pd.read_csv("Stops.txt")
    stops_df.columns = map(str.lower, stops_df.columns) 
    stops_df = stops_df.replace({np.nan: None, "": None})
    stops_df['stop_lat'] = pd.to_numeric(stops_df['stop_lat'], errors='coerce')
    stops_df['stop_lon'] = pd.to_numeric(stops_df['stop_lon'], errors='coerce')

    original_count = len(stops_df)
    stops_df.dropna(subset=['stop_lat', 'stop_lon'], inplace=True)
    if len(stops_df) < original_count:
        print(f"Warning: Dropped {original_count - len(stops_df)} rows due to missing lat/lon.")

    print("Creating GeoDataFrame...")
    stops_gdf = gpd.GeoDataFrame(
        stops_df,
        geometry=gpd.points_from_xy(stops_df.stop_lon, stops_df.stop_lat),
        crs="EPSG:4326" 
    )
    stops_gdf = stops_gdf.drop(columns=['stop_lat', 'stop_lon'])

    int_cols = ['wheelchair_boarding', 'location_type']
    for col in int_cols:
         if col in stops_gdf.columns:
            stops_gdf[col] = pd.to_numeric(stops_gdf[col], errors='coerce').astype('Int64')

    print("Writing STOPS data to PostGIS...")
    stops_gdf.to_postgis(
        name='stops',       # Table name (lowercase recommended)
        con=conn,           # Database connection engine
        schema='sa2project',# Target schema
        if_exists='append', # Append data to the existing (now empty) table
        index=False         # Don't write the DataFrame index
    )
    conn.commit() 
    index_sql = "CREATE INDEX idx_stops_geom ON stops USING gist(geometry);"
    conn.execute(text(index_sql))
    conn.commit()

except FileNotFoundError:
    print("ERROR: Stops.txt not found. Please check the path.")
except Exception as e:
    conn.rollback() # Rollback on error
    print(f"An error occurred during STOPS table processing: {e}")
# Out:
# Creating STOPS table with geometry...
# STOPS table created successfully with geometry column.
# Reading Stops.txt...
# Creating GeoDataFrame...
# Writing STOPS data to PostGIS...
# Successfully wrote STOPS data to PostGIS.
# Creating spatial index on stops geometry...
# Spatial index created successfully.

# %%
# ------------- Task 1: Load SA2 Boundaries -------------
print("Loading SA2 Boundaries shapefile...")
try:
    sa2_gdf = gpd.read_file('SA2/SA2_2021_AUST_GDA2020.shp')

    sa2_gdf.columns = map(str.lower, sa2_gdf.columns)
    if 'geometry' not in sa2_gdf.columns and 'geom' in sa2_gdf.columns:
         sa2_gdf = sa2_gdf.rename(columns={'geom': 'geometry'})
    elif 'geometry' not in sa2_gdf.columns:
         print("ERROR: Geometry column not found in SA2 shapefile.")
    conn.execute(text("SET search_path TO sa2project, public")) 
    sa2_gdf.to_postgis(
        name='sa2_boundaries',      # Choose a table name
        con=conn,                  # Your existing database connection engine
        schema='sa2project',       # Specify the schema
        if_exists='replace',       # Replace table if it already exists
        index=False                # Don't write the GeoDataFrame index as a column
    )
    conn.commit() # Commit the transaction
    print("Successfully wrote SA2 boundaries to PostGIS table 'sa2project.sa2_boundaries'.")

except FileNotFoundError:
    print("ERROR: SA2 shapefile not found. Please check the path 'SA2/SA2_2021_AUST_GDA2020.shp'.")
except Exception as e:
    conn.rollback()
    print(f"An error occurred during SA2 shapefile loading: {e}")
# Out:
# Loading SA2 Boundaries shapefile...
# Successfully wrote SA2 boundaries to PostGIS table 'sa2project.sa2_boundaries'.

# %% [markdown]
# c

# %%
sa4data = gpd.read_file("sa4/SA4_2021_AUST_GDA2020.dbf")
pd.set_option('display.max_rows', None)
filtered = sa4data[sa4data["GCC_NAME21"] == "Greater Sydney"] 
filtered
# Out:
#    SA4_CODE21                              SA4_NAME21 CHG_FLAG21  CHG_LBL21  \
# 1         102                           Central Coast          0  No change
# 14        115  Sydney - Baulkham Hills and Hawkesbury          0  No change
# 15        116                      Sydney - Blacktown          0  No change
# 16        117           Sydney - City and Inner South          0  No change
# 17        118                Sydney - Eastern Suburbs          0  No change
# 18        119               Sydney - Inner South West          0  No change
# 19        120                     Sydney - Inner West          0  No change
# 20        121       Sydney - North Sydney and Hornsby          0  No change
# 21        122               Sydney - Northern Beaches          0  No change
# 22        123               Sydney - Outer South West          0  No change
# 23        124  Sydney - Outer West and Blue Mountains          0  No change
# 24        125                     Sydney - Parramatta          0  No change
# 25        126                           Sydney - Ryde          0  No change
# 26        127                     Sydney - South West          0  No change
# 27        128                     Sydney - Sutherland          0  No change
#
#    GCC_CODE21      GCC_NAME21 STE_CODE21       STE_NAME21 AUS_CODE21  \
# 1       1GSYD  Greater Sydney          1  New South Wales        AUS
# 14      1GSYD  Greater Sydney          1  New South Wales        AUS
# 15      1GSYD  Greater Sydney          1  New South Wales        AUS
# 16      1GSYD  Greater Sydney          1  New South Wales        AUS
# 17      1GSYD  Greater Sydney          1  New South Wales        AUS
# 18      1GSYD  Greater Sydney          1  New South Wales        AUS
# 19      1GSYD  Greater Sydney          1  New South Wales        AUS
# 20      1GSYD  Greater Sydney          1  New South Wales        AUS
# 21      1GSYD  Greater Sydney          1  New South Wales        AUS
# 22      1GSYD  Greater Sydney          1  New South Wales        AUS
# 23      1GSYD  Greater Sydney          1  New South Wales        AUS
# 24      1GSYD  Greater Sydney          1  New South Wales        AUS
# 25      1GSYD  Greater Sydney          1  New South Wales        AUS
# 26      1GSYD  Greater Sydney          1  New South Wales        AUS
# 27      1GSYD  Greater Sydney          1  New South Wales        AUS
#
#    AUS_NAME21  AREASQKM21                                         LOCI_URI21  \
# 1   Australia   1681.0088  http://linked.data.gov.au/dataset/asgsed3/SA4/102
# 14  Australia   3251.4981  http://linked.data.gov.au/dataset/asgsed3/SA4/115
# 15  Australia    240.8835  http://linked.data.gov.au/dataset/asgsed3/SA4/116
# 16  Australia     66.1035  http://linked.data.gov.au/dataset/asgsed3/SA4/117
# 17  Australia     57.7342  http://linked.data.gov.au/dataset/asgsed3/SA4/118
# 18  Australia    163.9272  http://linked.data.gov.au/dataset/asgsed3/SA4/119
# 19  Australia     64.5491  http://linked.data.gov.au/dataset/asgsed3/SA4/120
# 20  Australia    275.0994  http://linked.data.gov.au/dataset/asgsed3/SA4/121
# 21  Australia    254.2072  http://linked.data.gov.au/dataset/asgsed3/SA4/122
# 22  Australia   1277.2421  http://linked.data.gov.au/dataset/asgsed3/SA4/123
# 23  Australia   3968.1294  http://linked.data.gov.au/dataset/asgsed3/SA4/124
# 24  Australia    162.8350  http://linked.data.gov.au/dataset/asgsed3/SA4/125
# 25  Australia     69.3368  http://linked.data.gov.au/dataset/asgsed3/SA4/126
# 26  Australia    540.2790  http://linked.data.gov.au/dataset/asgsed3/SA4/127
# 27  Australia    295.8525  http://linked.data.gov.au/dataset/asgsed3/SA4/128
#
#                                              geometry
# 1   MULTIPOLYGON (((151.31497 -33.55578, 151.31496...
# 14  MULTIPOLYGON (((151.15205 -33.52766, 151.15205...
# 15  POLYGON ((150.87089 -33.82385, 150.87078 -33.8...
# 16  MULTIPOLYGON (((151.19474 -33.85326, 151.19501...
# 17  MULTIPOLYGON (((151.26545 -33.9263, 151.26533 ...
# 18  POLYGON ((151.09654 -33.99094, 151.09654 -33.9...
# 19  MULTIPOLYGON (((151.17407 -33.84586, 151.17377...
# 20  MULTIPOLYGON (((151.17864 -33.5155, 151.17861 ...
# 21  MULTIPOLYGON (((151.32886 -33.66075, 151.32885...
# 22  POLYGON ((150.82039 -33.97522, 150.8204 -33.97...
# 23  POLYGON ((150.7718 -33.56681, 150.77186 -33.56...
# 24  POLYGON ((151.03452 -33.76232, 151.03499 -33.7...
# 25  POLYGON ((151.13306 -33.84098, 151.13304 -33.8...
# 26  POLYGON ((150.99181 -33.98115, 150.99193 -33.9...
# 27  POLYGON ((151.12487 -34.07979, 151.12489 -34.0...

# %%
def poi_in_bounding_box(xmin, ymin, xmax, ymax, filters={}):
    baseURL = 'https://maps.six.nsw.gov.au/arcgis/rest/services/public/NSW_POI/MapServer/0/query'
    params = {
        'geometry': f'{xmin},{ymin},{xmax},{ymax}',
        'geometryType': 'esriGeometryEnvelope',
        'inSR': '4326',
        'spatialRel': 'esriSpatialRelIntersects',
        'outFields': '*',
        'returnGeometry': 'true',
        'f': 'json',
        'where': ' AND '.join([f"{k}='{v}'" for k, v in filters.items()]) if filters else '1=1'
    }
    response = requests.get(baseURL, params=params)
    return json.loads(response.text)['features']

# %%
import time

sa2 = gpd.read_file('SA2/SA2_2021_AUST_GDA2020.shp')
selected_sa4 = 'Sydney - Blacktown'
sa2_in_sa4 = sa2[sa2['SA4_NAME21'] == selected_sa4]

pois = []
for idx, row in sa2_in_sa4.iterrows():
    xmin, ymin, xmax, ymax = row['geometry'].bounds  
    # Create a different variable name instead of reusing 'pois'
    poi_results = poi_in_bounding_box(xmin, ymin, xmax, ymax)

    for poi in poi_results:
        poi['SA2_NAME21'] = row['SA2_NAME21']  
        pois.append(poi)
    time.sleep(1)
pois
# Out:
# [{'attributes': {'objectid': 1836,
#    'topoid': 500245990,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'BREWONGLE WALKWAY',
#    'poilabel': 'BREWONGLE WALKWAY',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 89017,
#    'centroidid': None,
#    'shapeuuid': '0b0df18d-085e-30f0-b593-ad0595c63321',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89843351955943, 'y': -33.77774757918883},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1837,
#    'topoid': 500246012,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93537,
#    'centroidid': None,
#    'shapeuuid': '70934b1e-9583-3460-a0bd-8b2712535cc8',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90232411946172, 'y': -33.781609127365016},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1841,
#    'topoid': 500246067,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 85402,
#    'centroidid': None,
#    'shapeuuid': '66e1a476-5450-3b8a-aaab-dbd4107fec0f',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89955689426324, 'y': -33.78149960546565},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1842,
#    'topoid': 500246078,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93109,
#    'centroidid': None,
#    'shapeuuid': '2a3eaa8a-3fb9-3b1c-a730-a460c71dd892',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89939247741344, 'y': -33.77930863780092},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1849,
#    'topoid': 500246167,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87938,
#    'centroidid': None,
#    'shapeuuid': 'b3980d91-6ab7-3b3d-bf74-0a793d2263e1',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90574889797338, 'y': -33.781910352371575},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1850,
#    'topoid': 500246189,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 88069,
#    'centroidid': None,
#    'shapeuuid': '8b900347-62ce-3246-a779-cfbeeec78e8f',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91155731476894, 'y': -33.78185552854056},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1851,
#    'topoid': 500246200,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 88309,
#    'centroidid': None,
#    'shapeuuid': 'a712e46d-dec8-36c6-b423-fb868dc8bb66',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91084492020596, 'y': -33.77851430419446},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1852,
#    'topoid': 500246212,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 84385,
#    'centroidid': None,
#    'shapeuuid': '575c45e5-d50e-3cb3-bb8b-50d58a747176',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9120778175092, 'y': -33.77670673518522},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1853,
#    'topoid': 500246223,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 90253,
#    'centroidid': None,
#    'shapeuuid': 'e9499b72-6bc0-3bdf-8113-ebc189efea76',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.8935840776858, 'y': -33.780732826543954},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1854,
#    'topoid': 500246256,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'JOSEPH FRANK PARK',
#    'poilabel': 'JOSEPH FRANK PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1589469363000,
#    'enddate': 32503680000000,
#    'lastupdate': 1589469396398,
#    'msoid': 224285,
#    'centroidid': None,
#    'shapeuuid': '95c924ff-4047-3e80-a72d-ad71f210430b',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89744757990758, 'y': -33.76739592129559},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1856,
#    'topoid': 500246289,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'ALPHA PARK',
#    'poilabel': 'ALPHA PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87608,
#    'centroidid': None,
#    'shapeuuid': '432e1e3a-f451-336a-8a4e-bede68cecd1c',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90461731176953, 'y': -33.771756090867385},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1858,
#    'topoid': 500246311,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'BILLY GOAT HILL RESERVE',
#    'poilabel': 'BILLY GOAT HILL RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 86901,
#    'centroidid': None,
#    'shapeuuid': '4bd4fd4e-3c72-3b72-b18b-f24d1ebcf9c4',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91648037717334, 'y': -33.76682172470209},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1859,
#    'topoid': 500246323,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87845,
#    'centroidid': None,
#    'shapeuuid': '0b079c2e-6656-3592-96be-5ab7b76d53e0',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89799157718573, 'y': -33.75239901292558},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1860,
#    'topoid': 500246334,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 90846,
#    'centroidid': None,
#    'shapeuuid': '2ce1dbe8-c23f-3da8-9c76-eda61c4fba37',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90086384239038, 'y': -33.75185202199457},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1861,
#    'topoid': 500246345,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 90979,
#    'centroidid': None,
#    'shapeuuid': '763c4fc0-4f84-32bb-bec1-0bbabbe10010',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90001580491437, 'y': -33.74939070149965},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1863,
#    'topoid': 500246389,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 91212,
#    'centroidid': None,
#    'shapeuuid': '2fcebdf1-043e-3a0e-b0e0-6b510d4faef7',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9173863038829, 'y': -33.75420378450608},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1864,
#    'topoid': 500246411,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'KINGSFORD RESERVE',
#    'poilabel': 'KINGSFORD RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87309,
#    'centroidid': None,
#    'shapeuuid': '598232ad-3981-3a9b-b412-3263d1c70139',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92470163738102, 'y': -33.751693243133985},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1878,
#    'topoid': 500246600,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93413,
#    'centroidid': None,
#    'shapeuuid': '362aa85f-bdac-3218-880e-382140ab1823',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92348219594246, 'y': -33.77066607954255},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1879,
#    'topoid': 500246611,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93541,
#    'centroidid': None,
#    'shapeuuid': '47ef96dc-3a31-3a69-9be1-c6fe85a0205e',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92250085476644, 'y': -33.7681205154271},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1880,
#    'topoid': 500246622,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'CHRISTIES CORNER',
#    'poilabel': 'CHRISTIES CORNER',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1586965784000,
#    'enddate': 32503680000000,
#    'lastupdate': 1586965806680,
#    'msoid': 224200,
#    'centroidid': None,
#    'shapeuuid': 'edbe2c82-be0f-3a69-a40c-0a0b2fbf47d3',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9223682149215, 'y': -33.764938545048246},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1882,
#    'topoid': 500246667,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 85163,
#    'centroidid': None,
#    'shapeuuid': '173e7703-182e-3d48-af64-1e14ebecb565',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92289877519968, 'y': -33.77562464883571},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 1894,
#    'topoid': 500246833,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 84386,
#    'centroidid': None,
#    'shapeuuid': '49549ce0-3f1c-3fb4-981e-1ebe13228017',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9277237802026, 'y': -33.778063693829644},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2028,
#    'topoid': 500249178,
#    'poigroup': 2,
#    'poitype': 'High School',
#    'poiname': 'PATRICIAN BROTHERS COLLEGE BLACKTOWN',
#    'poilabel': 'PATRICIAN BROTHERS COLLEGE BLACKTOWN',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 34,
#    'accesscontrol': 1,
#    'startdate': 1341333072000,
#    'enddate': 32503680000000,
#    'lastupdate': 1341333074392,
#    'msoid': 142049,
#    'centroidid': None,
#    'shapeuuid': '29506518-6a0a-36d8-9d1c-f7833e6dde50',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90873548098443, 'y': -33.77408521059323},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2032,
#    'topoid': 500249267,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'MITCHELL RESERVE',
#    'poilabel': 'MITCHELL RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93163,
#    'centroidid': None,
#    'shapeuuid': '894c880c-71a5-32e5-94f1-c82be45e80df',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91745319333722, 'y': -33.78260670164379},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2037,
#    'topoid': 500253972,
#    'poigroup': 1,
#    'poitype': 'General Hospital',
#    'poiname': 'BLACKTOWN HOSPITAL',
#    'poilabel': 'BLACKTOWN HOSPITAL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 12,
#    'accesscontrol': 1,
#    'startdate': 1310130775000,
#    'enddate': 32503680000000,
#    'lastupdate': 1310130787188,
#    'msoid': 129380,
#    'centroidid': None,
#    'shapeuuid': 'b83b6b4f-7946-3c57-8c4a-8caf40fedf99',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91693003697367, 'y': -33.77552336434013},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2049,
#    'topoid': 500254372,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': 'MARAYONG OVAL',
#    'poilabel': 'MARAYONG OVAL',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 100012,
#    'centroidid': None,
#    'shapeuuid': '9eccbed3-2d97-3af4-a3ca-dd5d5bda8245',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89666375221148, 'y': -33.75014611342094},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2050,
#    'topoid': 500254383,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'CAMPBELL PARK',
#    'poilabel': 'CAMPBELL PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93661,
#    'centroidid': None,
#    'shapeuuid': '57ddf151-474e-3472-ae1f-c107b07fdc0c',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89720193110156, 'y': -33.76201912894689},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2148,
#    'topoid': 500259004,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'JEHOVAHS WITNESSES CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'JEHOVAHS WITNESSES',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 60354,
#    'centroidid': None,
#    'shapeuuid': 'a9cf663e-c7e7-3881-9ec4-ab39a8e541da',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9013071654746, 'y': -33.768428410145226},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2149,
#    'topoid': 500259027,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'ORTHODOX CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'ORTHODOX',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 58163,
#    'centroidid': None,
#    'shapeuuid': '86583181-66c2-3600-a5c5-69da65cdb809',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90186840860963, 'y': -33.77470942594896},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2150,
#    'topoid': 500259038,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'SEVENTH DAY ADVENTIST CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'SEVENTH DAY ADVENTIST',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 60355,
#    'centroidid': None,
#    'shapeuuid': '8f5cf9b7-cad3-35e4-bee9-1ea3bc6d4061',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90717119427455, 'y': -33.773671881356165},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2151,
#    'topoid': 500259082,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'FRANCIS PARK',
#    'poilabel': 'FRANCIS PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 95774,
#    'centroidid': None,
#    'shapeuuid': '1ae47e6f-0eb5-368a-88b4-6656fffbd0da',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90300931752952, 'y': -33.76664664006648},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2152,
#    'topoid': 500259093,
#    'poigroup': 3,
#    'poitype': 'Showground',
#    'poiname': 'BLACKTOWN SHOWGROUND',
#    'poilabel': 'BLACKTOWN SHOWGROUND',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 65,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 97278,
#    'centroidid': None,
#    'shapeuuid': 'd5c433a5-48dd-3ba1-ab51-c2c4c344d95d',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90066275361568, 'y': -33.765453391416884},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2164,
#    'topoid': 500259460,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'ORANA PARK',
#    'poilabel': 'ORANA PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 85183,
#    'centroidid': None,
#    'shapeuuid': '3c03eb3e-b4b8-3534-8d4f-04f397e2dc6d',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92133781405298, 'y': -33.77841916899122},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2165,
#    'topoid': 500259472,
#    'poigroup': 3,
#    'poitype': 'Sports Court',
#    'poiname': None,
#    'poilabel': 'TENNIS COURTS',
#    'poilabeltype': 'ALTERNATE',
#    'poialtlabel': 'TENNIS COURTS',
#    'poisourcefeatureoid': 66,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 97359,
#    'centroidid': None,
#    'shapeuuid': '8ac3a66a-0db3-3986-ba3d-b98adacfa9d3',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.921540194605, 'y': -33.77892477346894},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2168,
#    'topoid': 500259516,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'SALVATION ARMY CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'SALVATION ARMY',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 60357,
#    'centroidid': None,
#    'shapeuuid': '00f2ebd1-9bcd-31b9-81a4-6250c90a0dd4',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91410000157055, 'y': -33.77512842064231},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2169,
#    'topoid': 500259627,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'CATHOLIC CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'CATHOLIC',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1302515737000,
#    'enddate': 32503680000000,
#    'lastupdate': 1302515753319,
#    'msoid': 123558,
#    'centroidid': None,
#    'shapeuuid': 'efbdcc55-d7c0-3734-be59-cda9e85deccf',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92560866722172, 'y': -33.76054374759979},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2171,
#    'topoid': 500259671,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'CAVANAGH RESERVE',
#    'poilabel': 'CAVANAGH RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 93115,
#    'centroidid': None,
#    'shapeuuid': '698cd449-4744-3cd1-9ea3-85f0884379ca',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9241706647762, 'y': -33.75954702471841},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 2172,
#    'topoid': 500259682,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': 'FRED VASSEL FIELDS',
#    'poilabel': 'FRED VASSEL FIELDS',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 99128,
#    'centroidid': None,
#    'shapeuuid': '0b4fdcc4-2ba9-3351-ad4d-2701873a011a',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9242504351734, 'y': -33.74884551165103},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 4470,
#    'topoid': 500726827,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'TUABILLI PARK',
#    'poilabel': 'TUABILLI PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 95585,
#    'centroidid': None,
#    'shapeuuid': '244d9717-d4d2-32ed-a126-bb46f56f8357',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89453023544533, 'y': -33.77387506765765},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 4471,
#    'topoid': 500726829,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'WHEELER PARK',
#    'poilabel': 'WHEELER PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1582793660000,
#    'enddate': 32503680000000,
#    'lastupdate': 1582793691623,
#    'msoid': 223671,
#    'centroidid': None,
#    'shapeuuid': '44a25869-4e8a-318f-bad9-758b8b69a946',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92639331058814, 'y': -33.76470030919921},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 4472,
#    'topoid': 500726830,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'BAPTIST CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'BAPTIST',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 59279,
#    'centroidid': None,
#    'shapeuuid': '34ed7900-b870-3cb3-8222-0d2f720fbf94',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91650516259034, 'y': -33.764438740541564},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 4478,
#    'topoid': 500726845,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'MAURICE BOLTON RESERVE',
#    'poilabel': 'MAURICE BOLTON RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 85042,
#    'centroidid': None,
#    'shapeuuid': '057a7a25-f6d4-33ce-89da-fd4f3c90f478',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91696046111568, 'y': -33.773793262878215},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 9989,
#    'topoid': 501746239,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'MARAYONG HEIGHTS RESERVE',
#    'poilabel': 'MARAYONG HEIGHTS RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 86672,
#    'centroidid': None,
#    'shapeuuid': '47ff6242-55f2-3405-9eb2-c4c1a8a2e8d9',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89478634513281, 'y': -33.74397468258264},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 9990,
#    'topoid': 501746250,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 92137,
#    'centroidid': None,
#    'shapeuuid': '4dfd3dac-1d65-3676-9344-18d691df69f6',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.8981616327606, 'y': -33.74262075401293},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 10038,
#    'topoid': 501748139,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'FAULKLAND CRESCENT RESERVE',
#    'poilabel': 'FAULKLAND CRESCENT RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87448,
#    'centroidid': None,
#    'shapeuuid': '00b4858c-addf-36bb-8f79-a92506cd7709',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90959175601154, 'y': -33.740362853386216},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 10060,
#    'topoid': 501751517,
#    'poigroup': 1,
#    'poitype': 'Post Office',
#    'poiname': 'MARAYONG POST OFFICE',
#    'poilabel': 'MARAYONG POST OFFICE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 21,
#    'accesscontrol': 1,
#    'startdate': 1319808298000,
#    'enddate': 32503680000000,
#    'lastupdate': 1319808314723,
#    'msoid': 132570,
#    'centroidid': None,
#    'shapeuuid': '3cebebe7-12e2-38b5-a8e7-0cdb2b321148',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89980980415174, 'y': -33.74663657248001},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23765,
#    'topoid': 504300601,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219878,
#    'centroidid': None,
#    'shapeuuid': '895f9428-96e4-3173-b774-2dab84b4271e',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89465391998525, 'y': -33.77784148535726},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23875,
#    'topoid': 504300861,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87653,
#    'centroidid': None,
#    'shapeuuid': '95a2eaaf-b564-3bf4-a239-f2b453bd1840',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91790492375426, 'y': -33.77999471401846},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23879,
#    'topoid': 504300907,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219920,
#    'centroidid': None,
#    'shapeuuid': '9ef0a90a-bf62-37a0-a1ed-679c12b45539',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90844354199177, 'y': -33.765637475017314},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23880,
#    'topoid': 504300908,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219921,
#    'centroidid': None,
#    'shapeuuid': 'db86e9ac-928c-3a44-9ef2-0c0ca4ac1f59',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9082987111101, 'y': -33.76667506462818},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23881,
#    'topoid': 504300909,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219922,
#    'centroidid': None,
#    'shapeuuid': 'e2c4f491-03cf-3067-9154-07cb3661c055',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9097502215226, 'y': -33.768471903752626},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23882,
#    'topoid': 504300910,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219923,
#    'centroidid': None,
#    'shapeuuid': 'c239d582-7082-3add-9f5a-34ede7be03d0',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90666578772263, 'y': -33.76742115466028},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23883,
#    'topoid': 504300912,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219924,
#    'centroidid': None,
#    'shapeuuid': '5610feac-b180-38dd-ac6c-161dae3e941a',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9096811356874, 'y': -33.76798173520237},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23884,
#    'topoid': 504300914,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219925,
#    'centroidid': None,
#    'shapeuuid': '610af958-62cb-38a3-a10d-acbc0923c4c5',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90494692610517, 'y': -33.77068484142822},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23885,
#    'topoid': 504300915,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219926,
#    'centroidid': None,
#    'shapeuuid': '2fb5fe2d-79cd-3926-bdfa-faf5ca6e3cd4',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.90533571246857, 'y': -33.769357320908334},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23886,
#    'topoid': 504300916,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219927,
#    'centroidid': None,
#    'shapeuuid': '583a0b85-67cf-30ec-a70d-1f0211629cab',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9075767432011, 'y': -33.770825450522715},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23887,
#    'topoid': 504300917,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219928,
#    'centroidid': None,
#    'shapeuuid': 'a962c380-4ced-3041-8055-1aa4f8ae8f1c',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91101900113154, 'y': -33.77018313636389},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23888,
#    'topoid': 504300918,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219929,
#    'centroidid': None,
#    'shapeuuid': '5bc0e7aa-3ab8-3fae-9695-1f26aa68149e',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9128382764315, 'y': -33.771029757708774},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23889,
#    'topoid': 504300919,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219930,
#    'centroidid': None,
#    'shapeuuid': '6f4cf9a3-89fa-3c5c-b468-842f4374c14a',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91798804666414, 'y': -33.77109625251773},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23890,
#    'topoid': 504300920,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219931,
#    'centroidid': None,
#    'shapeuuid': '90dc91f7-41fb-362d-87cf-6d455fc226d2',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91417256478428, 'y': -33.772317244911925},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23891,
#    'topoid': 504300921,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219932,
#    'centroidid': None,
#    'shapeuuid': 'b8f2c421-5ddb-371b-8824-dfe2bb5f0dde',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9147049172014, 'y': -33.77241550820881},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23892,
#    'topoid': 504300922,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219933,
#    'centroidid': None,
#    'shapeuuid': '421bbe6e-a2fd-3e7d-9033-736a6d44e5ce',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91493608965666, 'y': -33.773026438866204},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23893,
#    'topoid': 504300923,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 88376,
#    'centroidid': None,
#    'shapeuuid': '3177d416-1abf-3470-ab19-d77b75b1a95f',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91511834525136, 'y': -33.77036044429947},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23905,
#    'topoid': 504300956,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': None,
#    'poilabel': 'BOWLING GREENS',
#    'poilabeltype': 'ALTERNATE',
#    'poialtlabel': 'BOWLING GREENS',
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 100356,
#    'centroidid': None,
#    'shapeuuid': '3668a2ed-8a7c-38df-ab8e-c1377f8829e4',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91363139180933, 'y': -33.775142772270975},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23906,
#    'topoid': 504300957,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 85617,
#    'centroidid': None,
#    'shapeuuid': 'cf84c56d-e198-3677-be2d-c27f24266f72',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92541780576659, 'y': -33.749872040183035},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23918,
#    'topoid': 504300989,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'MARAYONG PARK',
#    'poilabel': 'MARAYONG PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 89645,
#    'centroidid': None,
#    'shapeuuid': '9bb471f6-b349-3e76-87e4-ccc43ebb317e',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89709765376503, 'y': -33.74938964385077},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23919,
#    'topoid': 504300990,
#    'poigroup': 3,
#    'poitype': 'Sports Court',
#    'poiname': None,
#    'poilabel': 'TENNIS COURTS',
#    'poilabeltype': 'ALTERNATE',
#    'poialtlabel': 'TENNIS COURTS',
#    'poisourcefeatureoid': 66,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 98775,
#    'centroidid': None,
#    'shapeuuid': '622eb2c4-37d4-3c20-a0fb-6f93f0bcf89f',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89709579784568, 'y': -33.75060952485623},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23920,
#    'topoid': 504300992,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219944,
#    'centroidid': None,
#    'shapeuuid': '6402f82c-b099-374b-a5f3-0cf4e23496c3',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91295090001535, 'y': -33.76239810794069},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23921,
#    'topoid': 504300994,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'BAPTIST CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'BAPTIST',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 61653,
#    'centroidid': None,
#    'shapeuuid': 'ace32969-762b-3904-a91c-513b96432292',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9259841234846, 'y': -33.75302728056047},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23922,
#    'topoid': 504300995,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': None,
#    'poilabel': 'Sports Field',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 100038,
#    'centroidid': None,
#    'shapeuuid': 'a30c6ba9-c7fb-3d11-b3a6-fcb5f4a3246c',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92674458240694, 'y': -33.753810391677874},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23926,
#    'topoid': 504301001,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'COPTIC CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'COPTIC',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 61654,
#    'centroidid': None,
#    'shapeuuid': '3512d4bf-472d-3a35-9dbb-39d44abdba03',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9088647054346, 'y': -33.762331864033065},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23927,
#    'topoid': 504301003,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'FOURSQUARE GOSPEL CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'FOURSQUARE GOSPEL',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 59393,
#    'centroidid': None,
#    'shapeuuid': '8111eb3a-1a18-3514-af65-132467b5c47d',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91752935969353, 'y': -33.766439984265624},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23931,
#    'topoid': 504301010,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219947,
#    'centroidid': None,
#    'shapeuuid': '1896a64c-2b74-3459-aaa3-012ccb4a2257',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.89824283776736, 'y': -33.7745432253352},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23932,
#    'topoid': 504301011,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'UNITING CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'UNITING',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 60509,
#    'centroidid': None,
#    'shapeuuid': '5b25c471-04ef-3cb4-9050-a1b98b721871',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.91603822010228, 'y': -33.778433619376216},
#   'SA2_NAME21': 'Blacktown (East) - Kings Park'},
#  {'attributes': {'objectid': 23934,
#    'topoid': 504301014,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
# ...
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2036,
#    'topoid': 500253928,
#    'poigroup': 3,
#    'poitype': 'Golf Course',
#    'poiname': 'FOX HILL GOLF COURSE',
#    'poilabel': 'FOX HILL GOLF COURSE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 54,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 82353,
#    'centroidid': None,
#    'shapeuuid': 'f54d7da2-ee4e-3ca6-a281-a8aadbbbcd10',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'S'},
#   'geometry': {'x': 150.93352689064983, 'y': -33.80361876289939},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2166,
#    'topoid': 500259494,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'DUNCAN PARK',
#    'poilabel': 'DUNCAN PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 85421,
#    'centroidid': None,
#    'shapeuuid': '92269ffc-0c37-3277-a33e-e10d1e279472',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.93269592116425, 'y': -33.782893629558394},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2197,
#    'topoid': 500260426,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'HAROLD READ PARK',
#    'poilabel': 'HAROLD READ PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 90262,
#    'centroidid': None,
#    'shapeuuid': 'f1d3639b-d664-30a2-aaab-26f6cc101600',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.94217049827992, 'y': -33.80585529419255},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2199,
#    'topoid': 500260516,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'BAPTIST CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'BAPTIST',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 59241,
#    'centroidid': None,
#    'shapeuuid': 'f95db93e-c020-3987-b6eb-adbaea3880b6',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.94546310227395, 'y': -33.78814428975817},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2200,
#    'topoid': 500260527,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'PRESBYTERIAN CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'PRESBYTERIAN',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 61510,
#    'centroidid': None,
#    'shapeuuid': '37db4206-3cef-3fb1-b5d5-918bdfc2c651',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9504269688535, 'y': -33.78999376444204},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2202,
#    'topoid': 500260560,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'CATHOLIC CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'CATHOLIC',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 58551,
#    'centroidid': None,
#    'shapeuuid': '8e5b18d0-296c-3d93-929c-4582d1cfd01a',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.95079785358988, 'y': -33.792100811036754},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2203,
#    'topoid': 500260605,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'C V KELLY PARK',
#    'poilabel': 'C V KELLY PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 89018,
#    'centroidid': None,
#    'shapeuuid': '0c1f6313-c685-3ac7-8eef-9ca8c92774a7',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.94448672788323, 'y': -33.79410201923935},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 2204,
#    'topoid': 500260616,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'GIRRAWEEN PARK',
#    'poilabel': 'GIRRAWEEN PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87632,
#    'centroidid': None,
#    'shapeuuid': '1e8a8370-fea7-3178-8e58-2384c0ef0acf',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9453957915097, 'y': -33.79083704246806},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 4444,
#    'topoid': 500726787,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'TOOGAGAL RESERVE',
#    'poilabel': 'TOOGAGAL RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1295536553000,
#    'enddate': 32503680000000,
#    'lastupdate': 1295536556855,
#    'msoid': 121627,
#    'centroidid': None,
#    'shapeuuid': '2eefecd0-9187-362a-b5b2-f3a2638a72f8',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9442637660297, 'y': -33.79569629940003},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 4445,
#    'topoid': 500726788,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'DANDIE PARK',
#    'poilabel': 'DANDIE PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1295536553000,
#    'enddate': 32503680000000,
#    'lastupdate': 1295536556882,
#    'msoid': 121628,
#    'centroidid': None,
#    'shapeuuid': 'a32aa5bf-f163-3c4e-805b-4b08bc4f0c90',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.94842973999076, 'y': -33.80237911621012},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 4446,
#    'topoid': 500726789,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'LINLEE STREET PARK',
#    'poilabel': 'LINLEE STREET PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1418293920000,
#    'enddate': 32503680000000,
#    'lastupdate': 1418293942549,
#    'msoid': 176043,
#    'centroidid': None,
#    'shapeuuid': '348a5ff9-f4d5-3ab6-9e47-c49740b122c6',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9468423629848, 'y': -33.804869964493314},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 4479,
#    'topoid': 500726846,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'PORTICO PARK',
#    'poilabel': 'PORTICO PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 88086,
#    'centroidid': None,
#    'shapeuuid': '5984ac70-510b-3707-a1b5-9445bf2bffc1',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9508883354986, 'y': -33.78746586871407},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 4489,
#    'topoid': 500726863,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': None,
#    'poilabel': 'Park',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87959,
#    'centroidid': None,
#    'shapeuuid': 'f0c8c9e2-6420-3912-a490-a43c794362bb',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.93227504428395, 'y': -33.78964798831448},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 4490,
#    'topoid': 500726864,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'VANCOUVER RESERVE',
#    'poilabel': 'VANCOUVER RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87958,
#    'centroidid': None,
#    'shapeuuid': '3b663bb8-9e28-3940-b73f-604e909ff038',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9284271035779, 'y': -33.796648767118334},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 23945,
#    'topoid': 504301028,
#    'poigroup': 4,
#    'poitype': 'Parking Area',
#    'poiname': None,
#    'poilabel': 'Parking Area',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 152,
#    'accesscontrol': 1,
#    'startdate': 1553858193000,
#    'enddate': 32503680000000,
#    'lastupdate': 1553860296000,
#    'msoid': 219954,
#    'centroidid': None,
#    'shapeuuid': '14c5780b-734a-383b-9798-a7ad5ed39c4b',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.93982256263868, 'y': -33.782065518996575},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 23969,
#    'topoid': 504301073,
#    'poigroup': 3,
#    'poitype': 'Club',
#    'poiname': 'FOX HILLS GOLF CLUB',
#    'poilabel': 'FOX HILLS GOLF CLUB',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 41,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 3478,
#    'centroidid': None,
#    'shapeuuid': '256f1ce2-1e79-35da-b762-8161738aec44',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'S'},
#   'geometry': {'x': 150.9313514315431, 'y': -33.80528410904573},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 23972,
#    'topoid': 504301077,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'CHRISTIAN CITY CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'CHRISTIAN CITY',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 61869,
#    'centroidid': None,
#    'shapeuuid': 'b9743876-e026-310d-86d3-cf6596f66280',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'S'},
#   'geometry': {'x': 150.9280947637537, 'y': -33.80454164065856},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 23973,
#    'topoid': 504301078,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'MARDI STREET PARK',
#    'poilabel': 'MARDI STREET PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1418293920000,
#    'enddate': 32503680000000,
#    'lastupdate': 1418293942559,
#    'msoid': 176047,
#    'centroidid': None,
#    'shapeuuid': '8d342413-ddb5-35f2-bbd5-03054fcd42b3',
#    'changetype': 'M',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.94382678145806, 'y': -33.8040460488022},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 23977,
#    'topoid': 504301084,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'CATHOLIC CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'CATHOLIC',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 59394,
#    'centroidid': None,
#    'shapeuuid': '0adaf105-25a2-3e85-839f-4f5e9150c34b',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.94923537788358, 'y': -33.78819129650947},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 24018,
#    'topoid': 504301135,
#    'poigroup': 3,
#    'poitype': 'Sports Court',
#    'poiname': None,
#    'poilabel': 'TENNIS COURTS',
#    'poilabeltype': 'ALTERNATE',
#    'poialtlabel': 'TENNIS COURTS',
#    'poisourcefeatureoid': 66,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 99010,
#    'centroidid': None,
#    'shapeuuid': '68d93093-b680-3acd-9db7-e48e07633511',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92852343890894, 'y': -33.787243041814776},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 24019,
#    'topoid': 504301136,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': None,
#    'poilabel': 'Sports Field',
#    'poilabeltype': 'GENERIC',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 100795,
#    'centroidid': None,
#    'shapeuuid': '400031ac-2905-387f-80ee-2192a116b244',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9275011776752, 'y': -33.7884614440971},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 24020,
#    'topoid': 504301137,
#    'poigroup': 3,
#    'poitype': 'Sports Field',
#    'poiname': None,
#    'poilabel': 'OVAL',
#    'poilabeltype': 'ALTERNATE',
#    'poialtlabel': 'OVAL',
#    'poisourcefeatureoid': 67,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 102086,
#    'centroidid': None,
#    'shapeuuid': '94d1ec65-4364-3ef8-bde7-6f633df77f70',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92918442558323, 'y': -33.78827311964153},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 24225,
#    'topoid': 504301528,
#    'poigroup': 1,
#    'poitype': 'Place Of Worship',
#    'poiname': None,
#    'poilabel': 'PRESBYTERIAN CHURCH',
#    'poilabeltype': 'DERIVED',
#    'poialtlabel': 'PRESBYTERIAN',
#    'poisourcefeatureoid': 19,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 59399,
#    'centroidid': None,
#    'shapeuuid': '022edbd0-0b61-3a46-abbe-2409472e8f44',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.9490709430675, 'y': -33.797961335457686},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 27629,
#    'topoid': 504443809,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'GRANTHAM RESERVE',
#    'poilabel': 'GRANTHAM RESERVE',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 94483,
#    'centroidid': None,
#    'shapeuuid': '364109e3-6a42-396d-a63a-a399e54535e9',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.92825749626238, 'y': -33.78824500909369},
#   'SA2_NAME21': 'Toongabbie - West'},
#  {'attributes': {'objectid': 27634,
#    'topoid': 504443815,
#    'poigroup': 3,
#    'poitype': 'Park',
#    'poiname': 'JOHN SILVERTHORNE PARK',
#    'poilabel': 'JOHN SILVERTHORNE PARK',
#    'poilabeltype': 'NAMED',
#    'poialtlabel': None,
#    'poisourcefeatureoid': 61,
#    'accesscontrol': 1,
#    'startdate': 1285588392000,
#    'enddate': 32503680000000,
#    'lastupdate': 1285588392535,
#    'msoid': 87631,
#    'centroidid': None,
#    'shapeuuid': 'c817e2fd-38d7-33ab-a71a-d2ab7139873f',
#    'changetype': 'I',
#    'processstate': None,
#    'urbanity': 'U'},
#   'geometry': {'x': 150.93583021236077, 'y': -33.797505929584574},
#   'SA2_NAME21': 'Toongabbie - West'},
#  ...]

# %%
conn.commit()
create_table_query = """
DROP TABLE IF EXISTS PointsOfInterest;
CREATE TABLE PointsOfInterest (
    objectid BIGINT PRIMARY KEY,
    topoid BIGINT,
    poigroup TEXT,
    poitype TEXT,
    poiname TEXT,
    poilabel TEXT,
    poilabeltype TEXT,
    poialtlabel TEXT,
    poisourcefeatureoid BIGINT,
    accesscontrol TEXT,
    startdate bigint,
    enddate bigint,
    lastupdate bigint,
    msoid BIGINT,
    centroidid BIGINT,
    shapeuuid TEXT,
    changetype TEXT,
    processstate TEXT,
    urbanity TEXT,
    x FLOAT,
    y FLOAT,
    sa2_name21 TEXT
);
"""

# Execute the drop and create operations
conn.execute(text(create_table_query))

# Insert data query
insert_query = """
INSERT INTO PointsOfInterest (
    objectid, topoid, poigroup, poitype, poiname, poilabel, poilabeltype, poialtlabel,
    poisourcefeatureoid, accesscontrol, startdate, enddate, lastupdate,
    msoid, centroidid, shapeuuid, changetype, processstate, urbanity,
    x, y, sa2_name21
) VALUES (
    :objectid, :topoid, :poigroup, :poitype, :poiname, :poilabel, :poilabeltype, :poialtlabel,
    :poisourcefeatureoid, :accesscontrol, :startdate, :enddate, :lastupdate,
    :msoid, :centroidid, :shapeuuid, :changetype, :processstate, :urbanity,
    :x, :y, :SA2_NAME21
) ON CONFLICT (objectid) DO NOTHING;
"""

# Insert data
for poi in pois:
    attributes = poi.get('attributes', {})
    geometry = poi.get('geometry', {})
    data = {
        'objectid': attributes.get('objectid'),
        'topoid': attributes.get('topoid'),
        'poigroup': attributes.get('poigroup'),
        'poitype': attributes.get('poitype'),
        'poiname': attributes.get('poiname'),
        'poilabel': attributes.get('poilabel'),
        'poilabeltype': attributes.get('poilabeltype'),
        'poialtlabel': attributes.get('poialtlabel'),
        'poisourcefeatureoid': attributes.get('poisourcefeatureoid'),
        'accesscontrol': attributes.get('accesscontrol'),
        'startdate': attributes.get('startdate'),
        'enddate': attributes.get('enddate'),
        'lastupdate': attributes.get('lastupdate'),
        'msoid': attributes.get('msoid'),
        'centroidid': attributes.get('centroidid'),
        'shapeuuid': attributes.get('shapeuuid'),
        'changetype': attributes.get('changetype'),
        'processstate': attributes.get('processstate'),
        'urbanity': attributes.get('urbanity'),
        'x': geometry.get('x'),
        'y': geometry.get('y'),
        'SA2_NAME21': poi.get('SA2_NAME21')
    }
    conn.execute(text(insert_query), data)

print("Table created/recreated and data inserted successfully.")
# Out:
# Table created/recreated and data inserted successfully.

# %%
conn.execute(text("SET search_path TO sa2project, public"))
conn.commit()

# %%
import geopandas as gpd
import pandas as pd
from sqlalchemy import text
import os

catchment_dir = 'Catchments/catchments/'

# List the expected shapefiles - ADJUST FILENAMES if they are different!
catchment_files = {
    'Primary': os.path.join(catchment_dir, 'catchments_primary.shp'),
    'Secondary': os.path.join(catchment_dir, 'catchments_secondary.shp'),
    'Future': os.path.join(catchment_dir, 'catchments_future.shp') # Adjust if filename differs
}

all_catchments_list = [] # To store individual GeoDataFrames
base_crs = None # To store the CRS of the first file read

print("Loading and combining school catchment shapefiles...")

# Loop through the defined files
for catchment_type, file_path in catchment_files.items():
    if not os.path.exists(file_path):
        print(f"Warning: Shapefile not found at {file_path}. Skipping.")
        continue
    try:
        gdf = gpd.read_file(file_path)

        gdf['catchment_type'] = catchment_type

        if gdf.crs is None:
            print(f"Warning: CRS not set for {file_path}. Assuming GDA2020 (EPSG:7844). Set explicitly if different.")
            gdf.set_crs(epsg=7844, inplace=True) # Adjust EPSG if needed (e.g., 4283 for GDA94)

        if base_crs is None:
            base_crs = gdf.crs # Set the CRS from the first file
            print(f"Detected base CRS: {base_crs}")
        elif gdf.crs != base_crs:
            print(f"Warning: CRS mismatch for {file_path} ({gdf.crs}). Transforming to base CRS ({base_crs}).")
            gdf = gdf.to_crs(base_crs)
        # -----------------------------------------------------

        all_catchments_list.append(gdf)
        print(f"Successfully read {len(gdf)} features from {file_path}")

    except Exception as e:
        print(f"ERROR: Could not read or process {file_path}. Error: {e}")

if all_catchments_list:
    combined_catchments_gdf = pd.concat(all_catchments_list, ignore_index=True)
    print(f"Combined total of {len(combined_catchments_gdf)} catchment features.")

    combined_catchments_gdf.columns = map(str.lower, combined_catchments_gdf.columns)
    if 'geometry' not in combined_catchments_gdf.columns and 'geom' in combined_catchments_gdf.columns:
         combined_catchments_gdf = combined_catchments_gdf.rename(columns={'geom': 'geometry'})
    elif 'geometry' not in combined_catchments_gdf.columns:
         print("ERROR: Geometry column not found in combined catchment data. Cannot write to PostGIS.")
         combined_catchments_gdf = None 
    if combined_catchments_gdf is not None:
        try:
            print("Writing combined school catchments to PostGIS table 'sa2project.schoolcatchments'...")
            conn.execute(text("SET search_path TO sa2project, public"))
            conn.commit()

            combined_catchments_gdf.to_postgis(
                name='schoolcatchments',      # Table name
                con=conn,                     # Database connection engine
                schema='sa2project',          # Target schema
                if_exists='replace',          # Replace the table if it exists
                index=False                   # Don't write the GeoDataFrame index
            )
            conn.commit() # Commit transaction
            print("Successfully wrote combined data to PostGIS.")

            # Optional: Add a spatial index (HIGHLY RECOMMENDED)
            print("Creating spatial index on schoolcatchments geometry...")
            index_sql = "CREATE INDEX idx_schoolcatchments_geom ON sa2project.schoolcatchments USING gist(geometry);"
            conn.execute(text("DROP INDEX IF EXISTS sa2project.idx_schoolcatchments_geom;"))
            conn.execute(text(index_sql))
            conn.commit()
            print("Spatial index created successfully.")

        except Exception as e:
            conn.rollback() 
            print(f"An error occurred writing combined catchments to PostGIS: {e}")
else:
    print("No school catchment data loaded. Cannot write to PostGIS.")

# ----------------------------------------------------------
# Out:
# Loading and combining school catchment shapefiles...
# Detected base CRS: EPSG:4283
# Successfully read 1662 features from Catchments/catchments/catchments_primary.shp
# Successfully read 436 features from Catchments/catchments/catchments_secondary.shp
# Successfully read 30 features from Catchments/catchments/catchments_future.shp
# Combined total of 2128 catchment features.
# Writing combined school catchments to PostGIS table 'sa2project.schoolcatchments'...
# Successfully wrote combined data to PostGIS.
# Creating spatial index on schoolcatchments geometry...
# Spatial index created successfully.

# %%
def businesses_per_1000():
    
    sql = """
    SELECT B.sa2_name, B.total_businesses, P.total_people
    FROM Businesses B JOIN Population P ON B.sa2_name = P.sa2_name
    WHERE B.sa2_name in (SELECT distinct(sa2_name21) FROM PointsOfInterest) 
    and B.industry_name = 'Retail Trade'
    AND P.total_people > 100;
    """
    businesses = query(conn,sql)

    businesses_per_1000 = {}
    for idx, row in businesses.iterrows():
        sa2_name = row['sa2_name']
        total_businesses = row['total_businesses']
        total_people = row['total_people']

        per_1000 = (total_businesses / total_people) * 1000
        businesses_per_1000[sa2_name] = per_1000

    return businesses_per_1000 # returns Dictionary with key-value as sa2_name : number of businesses per 1000 people

def stop_counts(target_sa2_names):
    if not target_sa2_names:
        print("Warning: No target SA2 names provided for stop_counts.")
        return {}

    sa2_names_tuple = tuple(target_sa2_names)

    sql = """
    SELECT
        sa2.sa2_name21,
        COALESCE(COUNT(st.stop_id), 0) AS stop_count
    FROM
        sa2project.sa2_boundaries sa2 
    LEFT JOIN
        sa2project.stops st
        ON ST_Contains(ST_Transform(sa2.geometry, 4326), st.geometry)
    WHERE
        sa2.sa2_name21 IN :sa2_names_tuple 
    GROUP BY
        sa2.sa2_name21;
    """

    print("Executing PostGIS query to count stops per SA2...")
    stop_counts_df = query(conn, text(sql), args={'sa2_names_tuple': sa2_names_tuple}, df=True)

    if stop_counts_df is None or stop_counts_df.empty:
        print("Warning: stop_counts query returned no results.")
        return {name: 0 for name in target_sa2_names}

    stop_counts_dict = dict(zip(stop_counts_df['sa2_name21'], stop_counts_df['stop_count']))
    for name in target_sa2_names:
        if name not in stop_counts_dict:
            stop_counts_dict[name] = 0

    print("Stop counts calculated using PostGIS.")
    return stop_counts_dict

sa2_names_in_selected_sa4 = sa2_in_sa4['SA2_NAME21'].tolist()

def schools_per_1000(target_sa2_names, conn):
    if not target_sa2_names:
        print("Warning: No target SA2 names provided for schools_per_1000.")
        return {}

    sa2_names_tuple = tuple(target_sa2_names)

    sql = """
    WITH YoungPop AS (
        SELECT
            sa2_name,
            ("0-4_people" + "5-9_people" + "10-14_people" + "15-19_people") AS total_young_people
        FROM sa2project.population
        WHERE sa2_name IN :sa2_names_tuple
          AND ("0-4_people" + "5-9_people" + "10-14_people" + "15-19_people") >= 100
    ),
    CatchmentCounts AS (
        SELECT
            sa2.sa2_name21,
            COUNT(sc.ogc_fid) AS catchment_count
        FROM
            sa2project.sa2_boundaries sa2
        JOIN
            sa2project.schoolcatchments sc
            ON ST_Intersects(
                ST_Transform(sa2.geometry, 4326),
                ST_Transform(sc.geometry, 4326)
            )
        WHERE
            sa2.sa2_name21 IN :sa2_names_tuple -- Ensure we only process target SA2s
        GROUP BY
            sa2.sa2_name21
    )
    SELECT
        yp.sa2_name,
        (COALESCE(cc.catchment_count, 0) * 1000.0 / yp.total_young_people) AS schools_per_1000
    FROM
        YoungPop yp
    LEFT JOIN -- Use LEFT JOIN to keep all SA2s from YoungPop (those with >= 100 young people)
        CatchmentCounts cc ON yp.sa2_name = cc.sa2_name21; -- Match SA2 names
    """

    print("Executing PostGIS query to calculate schools per 1000 young people...")
    try:
        schools_ratio_df = query(conn, text(sql), args={'sa2_names_tuple': sa2_names_tuple}, df=True)

        if schools_ratio_df is None or schools_ratio_df.empty:
            print("Warning: schools_per_1000 query returned no results.")
            return {name: 0.0 for name in target_sa2_names}
        schools_ratio_dict = dict(zip(schools_ratio_df['sa2_name'], schools_ratio_df['schools_per_1000']))

        final_dict = {}
        young_pop_sa2s = set(query(conn, text("SELECT sa2_name FROM YoungPop"), df=True)['sa2_name']) # Re-query YoungPop SA2s
        for name in target_sa2_names:
             if name in young_pop_sa2s: # Only include SA2s that met the >=100 young people criteria
                final_dict[name] = schools_ratio_dict.get(name, 0.0) # Get score or default to 0

        print("Schools per 1000 young people calculated using PostGIS.")
        return final_dict

    except Exception as e:
        print(f"An error occurred during schools_per_1000 query: {e}")
        return {}


def POI_counts():
    sql = """
    SELECT sa2_name21, Count(*) as Poi_count
    FROM PointsOfInterest
    WHERE poigroup = '8'
    GROUP BY sa2_name21
    """
    poi_counts = query(conn,sql)

    if poi_counts is None or poi_counts.empty:
        print("Warning: POI_counts query returned no results.")
        return {}

    poi_dict = dict(zip(poi_counts['sa2_name21'], poi_counts['poi_count']))
    return poi_dict

# %%
conn.commit()
businesses_per_1000_people = businesses_per_1000()
transport_stop_counts = stop_counts(sa2_names_in_selected_sa4)
school_per_1000_people = schools_per_1000(sa2_in_sa4)
POI = POI_counts()

# %%
def z_score(data_dict):
    series = pd.Series(data_dict)
    z_series = (series - series.mean()) / series.std()
    return z_series.to_dict()

print(z_score(businesses_per_1000_people))
print(z_score(transport_stop_counts))
print(z_score(school_per_1000_people))
print(z_score(POI))
# Out:
# {'Blacktown (East) - Kings Park': 2.071190415555226, 'Blacktown (North) - Marayong': -0.43779635891160984, 'Doonside - Woodcroft': -0.43779635891160984, 'Lalor Park - Kings Langley': -0.43779635891160984, 'Blacktown - South': -0.43779635891160984, 'Blacktown - West': -0.43779635891160984, 'Seven Hills - Prospect': -0.43779635891160984, 'Toongabbie - West': -0.43779635891160984, 'Glenwood': -0.43779635891160984, 'Acacia Gardens': -0.43779635891160984, 'Quakers Hill': -0.43779635891160984, 'Kellyville Ridge - The Ponds': -0.43779635891160984, 'Marsden Park - Shanes Park': 2.3192649584898466, 'Riverstone': 2.662484889480276, 'Schofields (West) - Colebee': -0.43779635891160984, 'Schofields - East': 1.2651905557952392, 'Stanhope Gardens - Parklea': -0.43779635891160984, 'Bidwill - Hebersham - Emerton': -0.43779635891160984, 'Glendenning - Dean Park': -0.43779635891160984, 'Hassall Grove - Plumpton': -0.43779635891160984, 'Lethbridge Park - Tregear': -0.43779635891160984, 'Mount Druitt - Whalan': -0.43779635891160984, 'Rooty Hill - Minchinbury': -0.43779635891160984}
# {'Blacktown (East) - Kings Park': 2.284619982723459, 'Blacktown (North) - Marayong': 0.9374599021109881, 'Doonside - Woodcroft': -0.21934060189319904, 'Lalor Park - Kings Langley': 1.8746147407979241, 'Blacktown - South': -0.6732749768821839, 'Blacktown - West': -1.0320295635670267, 'Seven Hills - Prospect': -0.058267113993881854, 'Toongabbie - West': -1.0247080413897849, 'Glenwood': -0.27791277931113256, 'Acacia Gardens': -1.1638169627573771, 'Quakers Hill': 0.22727225091854406, 'Kellyville Ridge - The Ponds': -0.2559482127794075, 'Marsden Park - Shanes Park': 0.5347761823626951, 'Riverstone': 1.647647553303432, 'Schofields (West) - Colebee': -1.1711384849346187, 'Schofields - East': -0.9148852087311596, 'Stanhope Gardens - Parklea': -1.1711384849346187, 'Bidwill - Hebersham - Emerton': 0.9667459908199548, 'Glendenning - Dean Park': -0.7245256321228757, 'Hassall Grove - Plumpton': -0.3218419123745827, 'Lethbridge Park - Tregear': -0.13880385794354044, 'Mount Druitt - Whalan': 0.6665635815530455, 'Prospect Reservoir': 0.5567407488944202, 'Rooty Hill - Minchinbury': -0.5488090998690751}
# {'Blacktown (East) - Kings Park': 3.8368428858974197, 'Blacktown (North) - Marayong': 0.6615699280707231, 'Doonside - Woodcroft': -0.19393811251447068, 'Lalor Park - Kings Langley': 0.11702201045804196, 'Blacktown - South': -0.5345134852938893, 'Blacktown - West': -0.5345134852938893, 'Seven Hills - Prospect': 0.06565728123982477, 'Toongabbie - West': 0.17047416321286366, 'Glenwood': -0.5345134852938893, 'Acacia Gardens': -0.5345134852938893, 'Quakers Hill': -0.24191173312521913, 'Kellyville Ridge - The Ponds': 0.054645733171265684, 'Marsden Park - Shanes Park': 1.8603361453531624, 'Riverstone': -0.028612611726735876, 'Schofields (West) - Colebee': -0.5345134852938893, 'Schofields - East': -0.5345134852938893, 'Stanhope Gardens - Parklea': -0.5345134852938893, 'Bidwill - Hebersham - Emerton': -0.18746203277853832, 'Glendenning - Dean Park': -0.5345134852938893, 'Hassall Grove - Plumpton': -0.5345134852938893, 'Lethbridge Park - Tregear': -0.5345134852938893, 'Mount Druitt - Whalan': -0.2349753190255551, 'Rooty Hill - Minchinbury': -0.5345134852938893}
# {'Schofields (West) - Colebee': -1.1636466529285612, 'Lalor Park - Kings Langley': 1.2090371252059167, 'Glendenning - Dean Park': -0.5942025461762865, 'Stanhope Gardens - Parklea': -1.1636466529285612, 'Doonside - Woodcroft': -0.3094804928001492, 'Schofields - East': -0.6891098973016657, 'Seven Hills - Prospect': 0.07014891170136722, 'Toongabbie - West': -0.6891098973016657, 'Prospect Reservoir': -0.024758439424011885, 'Blacktown (North) - Marayong': 0.25996361395212547, 'Mount Druitt - Whalan': 2.0632032853343287, 'Lethbridge Park - Tregear': -0.21457314167477012, 'Rooty Hill - Minchinbury': -0.024758439424011885, 'Riverstone': 1.2090371252059167, 'Blacktown - South': -0.6891098973016657, 'Quakers Hill': -0.119665790549391, 'Glenwood': -0.6891098973016657, 'Hassall Grove - Plumpton': 0.25996361395212547, 'Blacktown - West': -0.8789245995524239, 'Bidwill - Hebersham - Emerton': -0.119665790549391, 'Kellyville Ridge - The Ponds': -0.119665790549391, 'Blacktown (East) - Kings Park': 2.917369445462741, 'Marsden Park - Shanes Park': -0.49929519505090747}

# %%
import numpy as np
def Score(x):
    return 1 / (1 + np.exp(-x))

def combined_resource_score(business_z, stop_z, school_z, poi_z):
    final_scores = {}
    all_sa2s = set(business_z) & set(stop_z) & set(school_z) & set(poi_z)

    for sa2 in all_sa2s:
        total_z = business_z[sa2] + stop_z[sa2] + school_z[sa2] + poi_z[sa2]
        final_scores[sa2] = Score(total_z) 
        # final_scores[sa2] = round(Score(total_z), 3) if we want to round to 3 d.p

    return final_scores

businesses_z_score = z_score(businesses_per_1000_people)
stops_z_score = z_score(transport_stop_counts)
schools_z_score = z_score(school_per_1000_people)
POI_z_score = z_score(POI)

scores = combined_resource_score(businesses_z_score, stops_z_score, schools_z_score, POI_z_score)
print(scores)
# Out:
# {'Quakers Hill': np.float64(0.3607520258717122), 'Blacktown (East) - Kings Park': np.float64(0.9999850386102371), 'Doonside - Woodcroft': np.float64(0.23856635055454292), 'Lethbridge Park - Tregear': np.float64(0.20987370680905412), 'Riverstone': np.float64(0.9958914044135062), 'Rooty Hill - Minchinbury': np.float64(0.1756824998683663), 'Glendenning - Dean Park': np.float64(0.09186791288640288), 'Hassall Grove - Plumpton': np.float64(0.2622729514025215), 'Schofields - East': np.float64(0.294564357175185), 'Seven Hills - Prospect': np.float64(0.41089728714403534), 'Lalor Park - Kings Langley': np.float64(0.9406365169282493), 'Schofields (West) - Colebee': np.float64(0.035328590080536175), 'Marsden Park - Shanes Park': np.float64(0.9854439005930826), 'Glenwood': np.float64(0.1257212044186272), 'Blacktown - West': np.float64(0.05298711104111019), 'Blacktown - South': np.float64(0.08829003121174904), 'Kellyville Ridge - The Ponds': np.float64(0.318914538680193), 'Blacktown (North) - Marayong': np.float64(0.8055260130129996), 'Bidwill - Hebersham - Emerton': np.float64(0.5552291754063607), 'Stanhope Gardens - Parklea': np.float64(0.035328590080536175), 'Mount Druitt - Whalan': np.float64(0.8866525376416154), 'Toongabbie - West': np.float64(0.12119735137200598)}
